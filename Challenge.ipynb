# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train_data.csv')

# %%
df.shape
# Out:
# (5531451, 190)

# %%
df.describe()
# Out:
#                 P_2          D_39           B_1           B_2           R_1  \
# count  5.485466e+06  5.531451e+06  5.531451e+06  5.529435e+06  5.531451e+06
# mean   6.563340e-01  1.531172e-01  1.240100e-01  6.214887e-01  7.880270e-02
# std    2.446494e-01  2.700709e-01  2.119869e-01  4.014877e-01  2.263971e-01
# min   -4.589548e-01  5.026190e-09 -7.588799e+00  9.192280e-09  1.534223e-09
# 25%    4.803307e-01  4.528464e-03  8.863645e-03  1.053313e-01  2.895934e-03
# 50%    6.942950e-01  9.056902e-03  3.132968e-02  8.143328e-01  5.782230e-03
# 75%    8.648159e-01  2.366407e-01  1.259019e-01  1.002403e+00  8.660590e-03
# max    1.010000e+00  5.389619e+00  1.324060e+00  1.010000e+00  3.256284e+00
#
#                 S_3          D_41           B_3           D_42          D_43  \
# count  4.510907e+06  5.529435e+06  5.529435e+06  791314.000000  3.873055e+06
# mean   2.258455e-01  5.978469e-02  1.325389e-01       0.184974  1.546841e-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: float64(185), int64(1), object(4)
# memory usage: 7.8+ GB

# %%
df.head()
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001733  0.008724  1.006838  0.009228  0.124035  0.008771  0.004709  ...
# 1  0.005775  0.004923  1.000653  0.006151  0.126750  0.000798  0.002714  ...
# 2  0.091505  0.021655  1.009672  0.006815  0.123977  0.007598  0.009423  ...
# 3  0.002455  0.013683  1.002700  0.001373  0.117169  0.000685  0.005531  ...
# 4  0.002483  0.015193  1.000727  0.007605  0.117325  0.004653  0.009312  ...
#
# ...

# %%
df['customer_ID'] = df['customer_ID'].apply(lambda x: int(x[-16:],16) ).astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: float64(185), int64(2), object(3)
# memory usage: 7.8+ GB

# %%
df.head()
# Out:
#            customer_ID         S_2       P_2      D_39       B_1       B_2  \
# 0 -4532153018459703766  2017-03-09  0.938469  0.001733  0.008724  1.006838
# 1 -4532153018459703766  2017-04-07  0.936665  0.005775  0.004923  1.000653
# 2 -4532153018459703766  2017-05-28  0.954180  0.091505  0.021655  1.009672
# 3 -4532153018459703766  2017-06-13  0.960384  0.002455  0.013683  1.002700
# 4 -4532153018459703766  2017-07-16  0.947248  0.002483  0.015193  1.000727
#
#         R_1       S_3      D_41       B_3  ...  D_136  D_137  D_138     D_139  \
# 0  0.009228  0.124035  0.008771  0.004709  ...    NaN    NaN    NaN  0.002427
# 1  0.006151  0.126750  0.000798  0.002714  ...    NaN    NaN    NaN  0.003954
# 2  0.006815  0.123977  0.007598  0.009423  ...    NaN    NaN    NaN  0.003269
# 3  0.001373  0.117169  0.000685  0.005531  ...    NaN    NaN    NaN  0.006117
# 4  0.007605  0.117325  0.004653  0.009312  ...    NaN    NaN    NaN  0.003671
#
# ...

# %%
df['S_2'] = pd.to_datetime(df['S_2'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: datetime64[ns](1), float64(185), int64(2), object(2)
# memory usage: 7.8+ GB

# %%
df.head()
# Out:
#            customer_ID        S_2       P_2      D_39       B_1       B_2  \
# 0 -4532153018459703766 2017-03-09  0.938469  0.001733  0.008724  1.006838
# 1 -4532153018459703766 2017-04-07  0.936665  0.005775  0.004923  1.000653
# 2 -4532153018459703766 2017-05-28  0.954180  0.091505  0.021655  1.009672
# 3 -4532153018459703766 2017-06-13  0.960384  0.002455  0.013683  1.002700
# 4 -4532153018459703766 2017-07-16  0.947248  0.002483  0.015193  1.000727
#
#         R_1       S_3      D_41       B_3  ...  D_136  D_137  D_138     D_139  \
# 0  0.009228  0.124035  0.008771  0.004709  ...    NaN    NaN    NaN  0.002427
# 1  0.006151  0.126750  0.000798  0.002714  ...    NaN    NaN    NaN  0.003954
# 2  0.006815  0.123977  0.007598  0.009423  ...    NaN    NaN    NaN  0.003269
# 3  0.001373  0.117169  0.000685  0.005531  ...    NaN    NaN    NaN  0.006117
# 4  0.007605  0.117325  0.004653  0.009312  ...    NaN    NaN    NaN  0.003671
#
# ...

# %%
col = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_66', 'D_68']
def cat_reducer(df, col):
    for m in col:
        x = df[m].mode()
        x = list(x)[0]
        df[m] = df[m].fillna(x).astype('int8')
cat_reducer(df, col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: datetime64[ns](1), float64(176), int64(2), int8(9), object(2)
# memory usage: 7.5+ GB

# %%
df.B_30.dtype
# Out:
# dtype('int8')

# %%
for m in df:
    if df[m].dtype == 'float64':
        df[m] = df[m].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: datetime64[ns](1), float32(176), int64(2), int8(9), object(2)
# memory usage: 3.9+ GB

# %%
df['B_31'] = df['B_31'].astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: datetime64[ns](1), float32(176), int64(1), int8(10), object(2)
# memory usage: 3.8+ GB

# %%
for m in df:
    if df[m].dtype == 'float32':
        df[m] = df[m].astype('float16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: datetime64[ns](1), float16(176), int64(1), int8(10), object(2)
# memory usage: 2.0+ GB

# %%
df.to_csv('train_reduced.csv')
